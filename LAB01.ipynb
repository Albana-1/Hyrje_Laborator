# %% [markdown]
# # **LABORATORI 01-HYRJE NE JUPYTERLAB DHE MJEDISIN E PUNES**
# ------------

# %% [markdown]
# ## **Kursi**: Hyrje në laborator (Fizikë & Shkenca Kompjuterike)
# ## **Studenti**: Albana Hoxha
# ## **Data**: 2026-03-10

# %% [markdown]
# ## **Qëllimi**
#
# Në këtë notebook do të dokumentojme:
#
# 1. Konfigurimin e "environment" lab (Conda).
# 2. Nisjen e JupyterLab dhe krijimin e notebook-ut.
# 3. Ekzekutimin e qelizave (cells) dhe kontrollin bazë të kernel-it.
# 4. Një test minimal të funksionimit të Python/NumPy/Matplotlib.
#
# --------------------------------------------

# %% [markdown]
# ## **Lista e kontrollit (Checklist)**
#
# * Miniconda/Anaconda i instaluar
# * Mjedisi lab i krijuar
# * JupyterLab nis pa probleme
# * Qelizat e kodit ekzekutohen (Shift+Enter)
# * Notebook-u ruhet dhe ngarkohet në GitHub

# %%
# Test minimal: Python funksionon?
a = 10
b = 2
a - b
# Out:
# 8

# %%
# Test minimal i Matplotlib

import matplotlib.pyplot as plt
data=[1, 2, 3]
plt.hist(data, bins=3)
plt.xlabel("koha  (s)")
plt.ylabel("shpejtesia (v)")
plt.title("Histogram test")
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Përfundim**
#
# - A funksionoi instalimi?
# - A u hap JupyterLab pa probleme?
# - A pati ndonjë gabim që u desh të zgjidhnit?
# - A e kuptoni dallimin mes qelizave Markdown dhe Code?
#
# **Përgjigje:**
#
# - Instalimi i mjedisit te punes u realizua me sukses.
# - Jupyter-lab u hap pa probleme dhe arrita te krijoj notebookun pa pasur veshtiresi.
# - Ne fillim kisha disa gabime te vogla gjate instalimit,por me ndihmen e profesorit ne klase arrita ti zgjidh.
# - Po,tani e kuptpj dallimin midis tyre.
# ***Markdown*** perdoret per te shkruajtur tekste te ndryshme,ndersa ***Code*** perdoret per ekzekutimin e kodeve.
